# %% [markdown]
# # 01. Data Generation
# Jera dataset sintetiku atleta boxe

# %%
import sys
sys.path.insert(0, "../src")

# %%
from data_generator import generate_dataset, save_raw_data
df = generate_dataset()
print(df.shape)
df.head()

# %%
print(df["performance_level"].value_counts())
print(df.groupby(["phase","performance_level"]).size().unstack(fill_value=0))

# %%
df.describe().round(2)

# %%
save_raw_data(df, path="../data/raw/boxing_dataset.csv")
